# %%
import sys

sys.path.append("../src")

# %%
from project_north.core.reducers import reduce_number
from project_north.core.validators import calculate_name_value

# %%
first_name = "Benjamin"

# %%
last_name = "Lebrun"

# %%
expression_total = calculate_name_value(f"{first_name} {last_name}")
expression_total
# Out:
# 59

# %%
expression_number = reduce_number(expression_total)
expression_number
# Out:
# 5

# %%
from project_north.numerology.expression import calculate_expression

# %%
calculate_expression("Benjamin", "Lebrun")
# Out:
# {'full_name': 'Benjamin Lebrun', 'total': 59, 'expression': 5}

# %%
calculate_expression("Benjamin", "Samuel", "Lebrun")
# Out:
# {'full_name': 'Benjamin Samuel Lebrun', 'total': 76, 'expression': 4}

# %%
calculate_expression("Benjamin", "Lebrun")
# Out:
# {'full_name': 'Benjamin Lebrun', 'total': 59, 'expression': 5}
